# %% [markdown]
# <a href="https://colab.research.google.com/github/CesarC15/projetoML/blob/main/scr/deteccao_anomalias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Setup Infraestrutura e Dados**

# %% [markdown]
# # **Modelagem Clássica**

# %% [markdown]
# # **Deep Learning & Avançado**

# %% [markdown]
# # **Avaliação e Validação Estatística**
